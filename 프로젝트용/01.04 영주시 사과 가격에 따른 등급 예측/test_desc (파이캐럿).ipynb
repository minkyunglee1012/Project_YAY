# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
import seaborn as sns
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier

# %%
df = pd.read_excel('./농넷_영주시_일별사과.xlsx')

# %%
from pycaret.classification import *

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

encoder.fit(df['등급명'])
df['등급명'] = encoder.transform(df['등급명'])
df
# Out:
#             DATE  거래단위        평균가격(원)  총거래물량(kg)  총거래금액(원)     시장명      법인명  \
# 0     2024-03-13  10.0   62366.666667     1800.0  11226000  서울가락도매     동화청과
# 1     2024-03-13  10.0   95000.000000     3840.0  36480000  서울가락도매     서울청과
# 2     2024-03-13  10.0   60900.000000     1200.0   7308000  수원도매시장     경기청과
# 3     2024-03-13  10.0   61300.000000      600.0   3678000  인천삼산도매     경인농산
# 4     2024-03-13  20.0  152875.568182     3520.0  26906100  안동도매시장     안동청과
# ...          ...   ...            ...        ...       ...     ...      ...
# 65184 2020-01-03  10.0   24833.333333     2400.0   5960000  서울가락도매  농협가락(공)
# 65185 2020-01-03  10.0   20000.000000      300.0    600000  서울가락도매  농협가락(공)
# 65186 2020-01-03  18.0   25200.000000     2700.0   3780000  구리도매시장  농협구리(공)
# 65187 2020-01-03  18.0   25200.000000     1620.0   2268000  구리도매시장  농협구리(공)
# 65188 2020-01-02  10.0   23825.000000     1200.0   2859000  광주서부도매  농협광주(공)
#
#       품목명   품종명   산지명 산지시군명  등급명
# 0      사과   미시마  경상북도   영주시    3
# 1      사과    후지  경상북도   영주시    3
# 2      사과   미얀마    경북   영주시    3
# 3      사과   미시마  경상북도   영주시    3
# 4      사과   미얀마    경북   영주시    0
# ...    ..   ...   ...   ...  ...
# 65184  사과   미안마    경북   영주시    3
# 65185  사과    후지    경북   영주시    3
# 65186  사과  기타사과    경북   영주시    3
# 65187  사과  기타사과    경북   영주시    3
# 65188  사과    후지    경북   영주시    3
#
# [65189 rows x 12 columns]

# %%
df_temp = df[['등급명', '총거래물량(kg)', '평균가격(원)', '총거래금액(원)', '거래단위']]
df_temp
# Out:
#        등급명  총거래물량(kg)        평균가격(원)  총거래금액(원)  거래단위
# 0        3     1800.0   62366.666667  11226000  10.0
# 1        3     3840.0   95000.000000  36480000  10.0
# 2        3     1200.0   60900.000000   7308000  10.0
# 3        3      600.0   61300.000000   3678000  10.0
# 4        0     3520.0  152875.568182  26906100  20.0
# ...    ...        ...            ...       ...   ...
# 65184    3     2400.0   24833.333333   5960000  10.0
# 65185    3      300.0   20000.000000    600000  10.0
# 65186    3     2700.0   25200.000000   3780000  18.0
# 65187    3     1620.0   25200.000000   2268000  18.0
# 65188    3     1200.0   23825.000000   2859000  10.0
#
# [65189 rows x 5 columns]

# %%
# Out:
# C:\Users\jhi08\AppData\Local\Temp\ipykernel_18600\3772546017.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].drop(index1)
# C:\Users\jhi08\AppData\Local\Temp\ipykernel_18600\3772546017.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].drop(index2)
# C:\Users\jhi08\AppData\Local\Temp\ipykernel_18600\3772546017.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].drop(index1)
# C:\Users\jhi08\AppData\Local\Temp\ipykernel_18600\3772546017.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].drop(index2)
# C:\Users\jhi08\AppData\Local\Temp\ipykernel_18600\3772546017.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].drop(index1)
# C:\Users\jhi08\AppData\Local\Temp\ipykernel_18600\3772546017.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].drop(index2)
# C:\Users\jhi08\AppData\Local\Temp\ipykernel_18600\3772546017.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].drop(index1)
# C:\Users\jhi08\AppData\Local\Temp\ipykernel_18600\3772546017.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].drop(index2)
#        등급명  총거래물량(kg)       평균가격(원)    총거래금액(원)  거래단위
# 0        3     1800.0  62366.666667  11226000.0  10.0
# 1        3        NaN  95000.000000         NaN  10.0
# 2        3     1200.0  60900.000000   7308000.0  10.0
# 3        3      600.0  61300.000000   3678000.0  10.0
# 4        0     3520.0           NaN         NaN  20.0
# ...    ...        ...           ...         ...   ...
# 65184    3     2400.0  24833.333333   5960000.0  10.0
# 65185    3      300.0  20000.000000    600000.0  10.0
# 65186    3     2700.0  25200.000000   3780000.0  18.0
# 65187    3     1620.0  25200.000000   2268000.0  18.0
# 65188    3     1200.0  23825.000000   2859000.0  10.0
#
# [65189 rows x 5 columns]

# %%
df_temp.isnull().sum()
# Out:
# 등급명          0
# 총거래물량(kg)    0
# 평균가격(원)      0
# 총거래금액(원)     0
# 거래단위         0
# dtype: int64

# %%
# Out:
# Unnamed: 0       0
# 등급명              0
# 총거래물량(kg)     4022
# 평균가격(원)        493
# 총거래금액(원)      4345
# 거래단위             0
# dtype: int64

# %%
import numpy as np
# scikit-learn에서 R의 MICE 패키지를 따라서 실험적으로 개발 중
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df_temp.isnull().sum()
# Out:
# 등급명          0
# 총거래물량(kg)    0
# 평균가격(원)      0
# 총거래금액(원)     0
# 거래단위         0
# dtype: int64

# %%
# Out:
#                 등급명  총거래물량(kg)   평균가격(원)  총거래금액(원)      거래단위
# 등급명        1.000000   0.150649 -0.258284  0.177232 -0.718478
# 총거래물량(kg)  0.150649   1.000000 -0.001281  0.860528 -0.028105
# 평균가격(원)   -0.258284  -0.001281  1.000000  0.156435  0.412628
# 총거래금액(원)   0.177232   0.860528  0.156435  1.000000 -0.115027
# 거래단위      -0.718478  -0.028105  0.412628 -0.115027  1.000000

# %%
s = setup(df_temp, target = '등급명')
# Out:
# <style type="text/css">
# #T_2ac5a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2ac5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ac5a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2ac5a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ac5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ac5a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2ac5a_row0_col1" class="data row0 col1" >5788</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ac5a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2ac5a_row1_col1" class="data row1 col1" >등급명</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ac5a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2ac5a_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2ac5a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2ac5a_row3_col1" class="data row3 col1" >(65189, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2ac5a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2ac5a_row4_col1" class="data row4 col1" >(65189, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2ac5a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2ac5a_row5_col1" class="data row5 col1" >(45632, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2ac5a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2ac5a_row6_col1" class="data row6 col1" >(19557, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2ac5a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2ac5a_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2ac5a_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_2ac5a_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2ac5a_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_2ac5a_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2ac5a_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_2ac5a_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2ac5a_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_2ac5a_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2ac5a_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_2ac5a_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2ac5a_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_2ac5a_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2ac5a_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_2ac5a_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2ac5a_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_2ac5a_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2ac5a_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_2ac5a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2ac5a_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_2ac5a_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2ac5a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2ac5a_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_2ac5a_row18_col1" class="data row18 col1" >8065</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()
s.setup(df_temp, target = '등급명')
# Out:
# <style type="text/css">
# #T_2abe7_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2abe7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2abe7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2abe7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2abe7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2abe7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2abe7_row0_col1" class="data row0 col1" >7095</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2abe7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2abe7_row1_col1" class="data row1 col1" >등급명</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2abe7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2abe7_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2abe7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2abe7_row3_col1" class="data row3 col1" >(65189, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2abe7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2abe7_row4_col1" class="data row4 col1" >(65189, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2abe7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2abe7_row5_col1" class="data row5 col1" >(45632, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2abe7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2abe7_row6_col1" class="data row6 col1" >(19557, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2abe7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2abe7_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2abe7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_2abe7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2abe7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_2abe7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2abe7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_2abe7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2abe7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_2abe7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2abe7_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_2abe7_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2abe7_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_2abe7_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2abe7_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_2abe7_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2abe7_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_2abe7_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2abe7_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_2abe7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2abe7_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_2abe7_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2abe7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2abe7_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_2abe7_row18_col1" class="data row18 col1" >a788</td>
#     </tr>
#   </tbody>
# </table>

# %%
# functional API
best = compare_models()

# OOP API
best = s.compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           15:34:13
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
# <style type="text/css">
# #T_fab94 th {
#   text-align: left;
# }
# #T_fab94_row0_col0, #T_fab94_row1_col0, #T_fab94_row1_col1, #T_fab94_row1_col2, #T_fab94_row1_col3, #T_fab94_row1_col4, #T_fab94_row1_col5, #T_fab94_row1_col6, #T_fab94_row1_col7, #T_fab94_row2_col0, #T_fab94_row2_col1, #T_fab94_row2_col2, #T_fab94_row2_col3, #T_fab94_row2_col4, #T_fab94_row2_col5, #T_fab94_row2_col6, #T_fab94_row2_col7, #T_fab94_row3_col0, #T_fab94_row3_col1, #T_fab94_row3_col2, #T_fab94_row3_col3, #T_fab94_row3_col4, #T_fab94_row3_col5, #T_fab94_row3_col6, #T_fab94_row3_col7, #T_fab94_row4_col0, #T_fab94_row4_col1, #T_fab94_row4_col2, #T_fab94_row4_col3, #T_fab94_row4_col4, #T_fab94_row4_col5, #T_fab94_row4_col6, #T_fab94_row4_col7, #T_fab94_row5_col0, #T_fab94_row5_col1, #T_fab94_row5_col2, #T_fab94_row5_col3, #T_fab94_row5_col4, #T_fab94_row5_col5, #T_fab94_row5_col6, #T_fab94_row5_col7, #T_fab94_row6_col0, #T_fab94_row6_col1, #T_fab94_row6_col2, #T_fab94_row6_col3, #T_fab94_row6_col4, #T_fab94_row6_col5, #T_fab94_row6_col6, #T_fab94_row6_col7, #T_fab94_row7_col0, #T_fab94_row7_col1, #T_fab94_row7_col2, #T_fab94_row7_col3, #T_fab94_row7_col4, #T_fab94_row7_col5, #T_fab94_row7_col6, #T_fab94_row7_col7, #T_fab94_row8_col0, #T_fab94_row8_col1, #T_fab94_row8_col2, #T_fab94_row8_col3, #T_fab94_row8_col4, #T_fab94_row8_col5, #T_fab94_row8_col6, #T_fab94_row8_col7, #T_fab94_row9_col0, #T_fab94_row9_col1, #T_fab94_row9_col2, #T_fab94_row9_col3, #T_fab94_row9_col4, #T_fab94_row9_col5, #T_fab94_row9_col6, #T_fab94_row9_col7, #T_fab94_row10_col0, #T_fab94_row10_col1, #T_fab94_row10_col2, #T_fab94_row10_col3, #T_fab94_row10_col4, #T_fab94_row10_col5, #T_fab94_row10_col6, #T_fab94_row10_col7, #T_fab94_row11_col0, #T_fab94_row11_col1, #T_fab94_row11_col2, #T_fab94_row11_col3, #T_fab94_row11_col4, #T_fab94_row11_col5, #T_fab94_row11_col6, #T_fab94_row11_col7, #T_fab94_row12_col0, #T_fab94_row12_col1, #T_fab94_row12_col2, #T_fab94_row12_col3, #T_fab94_row12_col4, #T_fab94_row12_col5, #T_fab94_row12_col6, #T_fab94_row12_col7, #T_fab94_row13_col0, #T_fab94_row13_col1, #T_fab94_row13_col2, #T_fab94_row13_col3, #T_fab94_row13_col4, #T_fab94_row13_col5, #T_fab94_row13_col6, #T_fab94_row13_col7, #T_fab94_row14_col0, #T_fab94_row14_col1, #T_fab94_row14_col2, #T_fab94_row14_col3, #T_fab94_row14_col4, #T_fab94_row14_col5, #T_fab94_row14_col6, #T_fab94_row14_col7 {
#   text-align: left;
# }
# #T_fab94_row0_col1, #T_fab94_row0_col2, #T_fab94_row0_col3, #T_fab94_row0_col4, #T_fab94_row0_col5, #T_fab94_row0_col6, #T_fab94_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fab94_row0_col8, #T_fab94_row1_col8, #T_fab94_row2_col8, #T_fab94_row3_col8, #T_fab94_row4_col8, #T_fab94_row5_col8, #T_fab94_row6_col8, #T_fab94_row7_col8, #T_fab94_row8_col8, #T_fab94_row9_col8, #T_fab94_row10_col8, #T_fab94_row11_col8, #T_fab94_row12_col8, #T_fab94_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fab94_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fab94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fab94_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fab94_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fab94_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fab94_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fab94_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fab94_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fab94_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fab94_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_fab94_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fab94_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_fab94_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fab94_row0_col1" class="data row0 col1" >0.7188</td>
#       <td id="T_fab94_row0_col2" class="data row0 col2" >0.8803</td>
#       <td id="T_fab94_row0_col3" class="data row0 col3" >0.7188</td>
#       <td id="T_fab94_row0_col4" class="data row0 col4" >0.7137</td>
#       <td id="T_fab94_row0_col5" class="data row0 col5" >0.6989</td>
#       <td id="T_fab94_row0_col6" class="data row0 col6" >0.5839</td>
#       <td id="T_fab94_row0_col7" class="data row0 col7" >0.5959</td>
#       <td id="T_fab94_row0_col8" class="data row0 col8" >0.3740</td>
#     </tr>
#     <tr>
#       <th id="T_fab94_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_fab94_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_fab94_row1_col1" class="data row1 col1" >0.7160</td>
#       <td id="T_fab94_row1_col2" class="data row1 col2" >0.8798</td>
#       <td id="T_fab94_row1_col3" class="data row1 col3" >0.7160</td>
#       <td id="T_fab94_row1_col4" class="data row1 col4" >0.7099</td>
#       <td id="T_fab94_row1_col5" class="data row1 col5" >0.6969</td>
#       <td id="T_fab94_row1_col6" class="data row1 col6" >0.5802</td>
#       <td id="T_fab94_row1_col7" class="data row1 col7" >0.5915</td>
#       <td id="T_fab94_row1_col8" class="data row1 col8" >2.0240</td>
#     </tr>
#     <tr>
#       <th id="T_fab94_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_fab94_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_fab94_row2_col1" class="data row2 col1" >0.7127</td>
#       <td id="T_fab94_row2_col2" class="data row2 col2" >0.8773</td>
#       <td id="T_fab94_row2_col3" class="data row2 col3" >0.7127</td>
#       <td id="T_fab94_row2_col4" class="data row2 col4" >0.7044</td>
#       <td id="T_fab94_row2_col5" class="data row2 col5" >0.6931</td>
#       <td id="T_fab94_row2_col6" class="data row2 col6" >0.5755</td>
#       <td id="T_fab94_row2_col7" class="data row2 col7" >0.5863</td>
#       <td id="T_fab94_row2_col8" class="data row2 col8" >0.3650</td>
#     </tr>
#     <tr>
#       <th id="T_fab94_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_fab94_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_fab94_row3_col1" class="data row3 col1" >0.6818</td>
#       <td id="T_fab94_row3_col2" class="data row3 col2" >0.8391</td>
#       <td id="T_fab94_row3_col3" class="data row3 col3" >0.6818</td>
#       <td id="T_fab94_row3_col4" class="data row3 col4" >0.6559</td>
#       <td id="T_fab94_row3_col5" class="data row3 col5" >0.6410</td>
#       <td id="T_fab94_row3_col6" class="data row3 col6" >0.5217</td>
#       <td id="T_fab94_row3_col7" class="data row3 col7" >0.5387</td>
#       <td id="T_fab94_row3_col8" class="data row3 col8" >0.1660</td>
#     </tr>
#     <tr>
#       <th id="T_fab94_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_fab94_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_fab94_row4_col1" class="data row4 col1" >0.6711</td>
#       <td id="T_fab94_row4_col2" class="data row4 col2" >0.8528</td>
#       <td id="T_fab94_row4_col3" class="data row4 col3" >0.6711</td>
#       <td id="T_fab94_row4_col4" class="data row4 col4" >0.6521</td>
#       <td id="T_fab94_row4_col5" class="data row4 col5" >0.5998</td>
#       <td id="T_fab94_row4_col6" class="data row4 col6" >0.4976</td>
#       <td id="T_fab94_row4_col7" class="data row4 col7" >0.5290</td>
#       <td id="T_fab94_row4_col8" class="data row4 col8" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_fab94_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_fab94_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_fab94_row5_col1" class="data row5 col1" >0.6610</td>
#       <td id="T_fab94_row5_col2" class="data row5 col2" >0.8295</td>
#       <td id="T_fab94_row5_col3" class="data row5 col3" >0.6610</td>
#       <td id="T_fab94_row5_col4" class="data row5 col4" >0.6132</td
# <style type="text/css">
# #T_da638 th {
#   text-align: left;
# }
# #T_da638_row0_col0, #T_da638_row1_col0, #T_da638_row1_col1, #T_da638_row1_col2, #T_da638_row1_col3, #T_da638_row1_col4, #T_da638_row1_col5, #T_da638_row1_col6, #T_da638_row1_col7, #T_da638_row2_col0, #T_da638_row2_col1, #T_da638_row2_col2, #T_da638_row2_col3, #T_da638_row2_col4, #T_da638_row2_col5, #T_da638_row2_col6, #T_da638_row2_col7, #T_da638_row3_col0, #T_da638_row3_col1, #T_da638_row3_col2, #T_da638_row3_col3, #T_da638_row3_col4, #T_da638_row3_col5, #T_da638_row3_col6, #T_da638_row3_col7, #T_da638_row4_col0, #T_da638_row4_col1, #T_da638_row4_col2, #T_da638_row4_col3, #T_da638_row4_col4, #T_da638_row4_col5, #T_da638_row4_col6, #T_da638_row4_col7, #T_da638_row5_col0, #T_da638_row5_col1, #T_da638_row5_col2, #T_da638_row5_col3, #T_da638_row5_col4, #T_da638_row5_col5, #T_da638_row5_col6, #T_da638_row5_col7, #T_da638_row6_col0, #T_da638_row6_col1, #T_da638_row6_col2, #T_da638_row6_col3, #T_da638_row6_col4, #T_da638_row6_col5, #T_da638_row6_col6, #T_da638_row6_col7, #T_da638_row7_col0, #T_da638_row7_col1, #T_da638_row7_col2, #T_da638_row7_col3, #T_da638_row7_col4, #T_da638_row7_col5, #T_da638_row7_col6, #T_da638_row7_col7, #T_da638_row8_col0, #T_da638_row8_col1, #T_da638_row8_col2, #T_da638_row8_col3, #T_da638_row8_col4, #T_da638_row8_col5, #T_da638_row8_col6, #T_da638_row8_col7, #T_da638_row9_col0, #T_da638_row9_col1, #T_da638_row9_col2, #T_da638_row9_col3, #T_da638_row9_col4, #T_da638_row9_col5, #T_da638_row9_col6, #T_da638_row9_col7, #T_da638_row10_col0, #T_da638_row10_col1, #T_da638_row10_col2, #T_da638_row10_col3, #T_da638_row10_col4, #T_da638_row10_col5, #T_da638_row10_col6, #T_da638_row10_col7, #T_da638_row11_col0, #T_da638_row11_col1, #T_da638_row11_col2, #T_da638_row11_col3, #T_da638_row11_col4, #T_da638_row11_col5, #T_da638_row11_col6, #T_da638_row11_col7, #T_da638_row12_col0, #T_da638_row12_col1, #T_da638_row12_col2, #T_da638_row12_col3, #T_da638_row12_col4, #T_da638_row12_col5, #T_da638_row12_col6, #T_da638_row12_col7, #T_da638_row13_col0, #T_da638_row13_col1, #T_da638_row13_col2, #T_da638_row13_col3, #T_da638_row13_col4, #T_da638_row13_col5, #T_da638_row13_col6, #T_da638_row13_col7, #T_da638_row14_col0, #T_da638_row14_col1, #T_da638_row14_col2, #T_da638_row14_col3, #T_da638_row14_col4, #T_da638_row14_col5, #T_da638_row14_col6, #T_da638_row14_col7 {
#   text-align: left;
# }
# #T_da638_row0_col1, #T_da638_row0_col2, #T_da638_row0_col3, #T_da638_row0_col4, #T_da638_row0_col5, #T_da638_row0_col6, #T_da638_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_da638_row0_col8, #T_da638_row1_col8, #T_da638_row2_col8, #T_da638_row3_col8, #T_da638_row4_col8, #T_da638_row5_col8, #T_da638_row6_col8, #T_da638_row7_col8, #T_da638_row8_col8, #T_da638_row9_col8, #T_da638_row10_col8, #T_da638_row11_col8, #T_da638_row12_col8, #T_da638_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_da638_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_da638">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da638_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_da638_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_da638_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_da638_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_da638_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_da638_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_da638_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_da638_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_da638_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da638_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_da638_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_da638_row0_col1" class="data row0 col1" >0.7194</td>
#       <td id="T_da638_row0_col2" class="data row0 col2" >0.8815</td>
#       <td id="T_da638_row0_col3" class="data row0 col3" >0.7194</td>
#       <td id="T_da638_row0_col4" class="data row0 col4" >0.7132</td>
#       <td id="T_da638_row0_col5" class="data row0 col5" >0.6992</td>
#       <td id="T_da638_row0_col6" class="data row0 col6" >0.5848</td>
#       <td id="T_da638_row0_col7" class="data row0 col7" >0.5965</td>
#       <td id="T_da638_row0_col8" class="data row0 col8" >0.3750</td>
#     </tr>
#     <tr>
#       <th id="T_da638_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_da638_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_da638_row1_col1" class="data row1 col1" >0.7161</td>
#       <td id="T_da638_row1_col2" class="data row1 col2" >0.8805</td>
#       <td id="T_da638_row1_col3" class="data row1 col3" >0.7161</td>
#       <td id="T_da638_row1_col4" class="data row1 col4" >0.7079</td>
#       <td id="T_da638_row1_col5" class="data row1 col5" >0.6963</td>
#       <td id="T_da638_row1_col6" class="data row1 col6" >0.5801</td>
#       <td id="T_da638_row1_col7" class="data row1 col7" >0.5911</td>
#       <td id="T_da638_row1_col8" class="data row1 col8" >1.9820</td>
#     </tr>
#     <tr>
#       <th id="T_da638_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_da638_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_da638_row2_col1" class="data row2 col1" >0.7143</td>
#       <td id="T_da638_row2_col2" class="data row2 col2" >0.8781</td>
#       <td id="T_da638_row2_col3" class="data row2 col3" >0.7143</td>
#       <td id="T_da638_row2_col4" class="data row2 col4" >0.7045</td>
#       <td id="T_da638_row2_col5" class="data row2 col5" >0.6942</td>
#       <td id="T_da638_row2_col6" class="data row2 col6" >0.5776</td>
#       <td id="T_da638_row2_col7" class="data row2 col7" >0.5882</td>
#       <td id="T_da638_row2_col8" class="data row2 col8" >0.2010</td>
#     </tr>
#     <tr>
#       <th id="T_da638_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_da638_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_da638_row3_col1" class="data row3 col1" >0.6824</td>
#       <td id="T_da638_row3_col2" class="data row3 col2" >0.8389</td>
#       <td id="T_da638_row3_col3" class="data row3 col3" >0.6824</td>
#       <td id="T_da638_row3_col4" class="data row3 col4" >0.6567</td>
#       <td id="T_da638_row3_col5" class="data row3 col5" >0.6396</td>
#       <td id="T_da638_row3_col6" class="data row3 col6" >0.5219</td>
#       <td id="T_da638_row3_col7" class="data row3 col7" >0.5402</td>
#       <td id="T_da638_row3_col8" class="data row3 col8" >0.1810</td>
#     </tr>
#     <tr>
#       <th id="T_da638_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_da638_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_da638_row4_col1" class="data row4 col1" >0.6729</td>
#       <td id="T_da638_row4_col2" class="data row4 col2" >0.8530</td>
#       <td id="T_da638_row4_col3" class="data row4 col3" >0.6729</td>
#       <td id="T_da638_row4_col4" class="data row4 col4" >0.6540</td>
#       <td id="T_da638_row4_col5" class="data row4 col5" >0.6011</td>
#       <td id="T_da638_row4_col6" class="data row4 col6" >0.5003</td>
#       <td id="T_da638_row4_col7" class="data row4 col7" >0.5319</td>
#       <td id="T_da638_row4_col8" class="data row4 col8" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_da638_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_da638_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_da638_row5_col1" class="data row5 col1" >0.6619</td>
#       <td id="T_da638_row5_col2" class="data row5 col2" >0.8302</td>
#       <td id="T_da638_row5_col3" class="data row5 col3" >0.6619</td>
#       <td id="T_da638_row5_col4" class="data row5 col4" >0.6122</td

# %%
print(best)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=7095, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
# functional API
evaluate_model(best)

# OOP API
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# functional API
plot_model(best, plot = 'auc')

# OOP API
s.plot_model(best, plot = 'auc')

# %%
# functional API
plot_model(best, plot = 'confusion_matrix')

# OOP API
s.plot_model(best, plot = 'confusion_matrix')

# %%
# functional API
predict_model(best)

# OOP API
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c090">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c090_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5c090_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5c090_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5c090_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5c090_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5c090_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5c090_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5c090_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c090_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c090_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5c090_row0_col1" class="data row0 col1" >0.7288</td>
#       <td id="T_5c090_row0_col2" class="data row0 col2" >0.8928</td>
#       <td id="T_5c090_row0_col3" class="data row0 col3" >0.7288</td>
#       <td id="T_5c090_row0_col4" class="data row0 col4" >0.7259</td>
#       <td id="T_5c090_row0_col5" class="data row0 col5" >0.7099</td>
#       <td id="T_5c090_row0_col6" class="data row0 col6" >0.5988</td>
#       <td id="T_5c090_row0_col7" class="data row0 col7" >0.6107</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0be56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0be56_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0be56_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0be56_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0be56_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0be56_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0be56_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0be56_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0be56_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0be56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0be56_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0be56_row0_col1" class="data row0 col1" >0.7182</td>
#       <td id="T_0be56_row0_col2" class="data row0 col2" >0.8762</td>
#       <td id="T_0be56_row0_col3" class="data row0 col3" >0.7182</td>
#       <td id="T_0be56_row0_col4" class="data row0 col4" >0.7135</td>
#       <td id="T_0be56_row0_col5" class="data row0 col5" >0.6982</td>
#       <td id="T_0be56_row0_col6" class="data row0 col6" >0.5828</td>
#       <td id="T_0be56_row0_col7" class="data row0 col7" >0.5949</td>
#     </tr>
#   </tbody>
# </table>
#        총거래물량(kg)       평균가격(원)  총거래금액(원)  거래단위  등급명  prediction_label  \
# 60179       20.0   2000.000000      2000  20.0    0                 0
# 2023      3180.0  69171.695312  10998300  20.0    2                 0
# 27736     1650.0  28004.242188   4620700  10.0    3                 3
# 9624      1870.0  33506.953125   6265800  10.0    3                 3
# 51535     2400.0  60345.832031   7241500  20.0    0                 0
# ...          ...           ...       ...   ...  ...               ...
# 57102     1550.0  34183.871094   5298500  10.0    2                 3
# 51008     1020.0  39778.429688   2028700  20.0    0                 0
# 3723      1250.0  63240.000000   7905000  10.0    3                 3
# 32108       80.0  24600.000000     98400  20.0    0                 0
# 43070      600.0  17266.666016   1036000  10.0    3                 3
#
#        prediction_score
# 60179            0.6352
# 2023             0.4939
# 27736            0.9511
# 9624             0.9456
# 51535            0.5807
# ...                 ...
# 57102            0.9232
# 51008            0.4895
# 3723             0.8988
# 32108            0.6924
# 43070            0.6175
#
# [19557 rows x 7 columns]

# %%
# functional API
predictions = predict_model(best, data=df_temp)
predictions.head()

# OOP API
predictions = s.predict_model(best, data=df_temp)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7d4ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d4ff_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7d4ff_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7d4ff_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7d4ff_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7d4ff_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7d4ff_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7d4ff_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7d4ff_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d4ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d4ff_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7d4ff_row0_col1" class="data row0 col1" >0.7285</td>
#       <td id="T_7d4ff_row0_col2" class="data row0 col2" >0.8937</td>
#       <td id="T_7d4ff_row0_col3" class="data row0 col3" >0.7285</td>
#       <td id="T_7d4ff_row0_col4" class="data row0 col4" >0.7262</td>
#       <td id="T_7d4ff_row0_col5" class="data row0 col5" >0.7094</td>
#       <td id="T_7d4ff_row0_col6" class="data row0 col6" >0.5982</td>
#       <td id="T_7d4ff_row0_col7" class="data row0 col7" >0.6104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_91fff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91fff_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_91fff_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_91fff_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_91fff_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_91fff_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_91fff_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_91fff_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_91fff_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91fff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91fff_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_91fff_row0_col1" class="data row0 col1" >0.7285</td>
#       <td id="T_91fff_row0_col2" class="data row0 col2" >0.8937</td>
#       <td id="T_91fff_row0_col3" class="data row0 col3" >0.7285</td>
#       <td id="T_91fff_row0_col4" class="data row0 col4" >0.7262</td>
#       <td id="T_91fff_row0_col5" class="data row0 col5" >0.7094</td>
#       <td id="T_91fff_row0_col6" class="data row0 col6" >0.5982</td>
#       <td id="T_91fff_row0_col7" class="data row0 col7" >0.6104</td>
#     </tr>
#   </tbody>
# </table>
#    총거래물량(kg)        평균가격(원)  총거래금액(원)  거래단위  등급명  prediction_label  \
# 0     1800.0   62366.667969  11226000  10.0    3                 3
# 1     3840.0   95000.000000  36480000  10.0    3                 3
# 2     1200.0   60900.000000   7308000  10.0    3                 3
# 3      600.0   61300.000000   3678000  10.0    3                 3
# 4     3520.0  152875.562500  26906100  20.0    0                 0
#
#    prediction_score
# 0            0.9048
# 1            0.9884
# 2            0.9106
# 3            0.8864
# 4            0.6484

# %%
# functional API
predictions = predict_model(best, data=df_temp, raw_score=True)
predictions.head()

# OOP API
predictions = s.predict_model(best, data=df_temp, raw_score=True)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d919">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d919_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0d919_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0d919_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0d919_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0d919_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0d919_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0d919_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0d919_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d919_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d919_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0d919_row0_col1" class="data row0 col1" >0.7285</td>
#       <td id="T_0d919_row0_col2" class="data row0 col2" >0.8937</td>
#       <td id="T_0d919_row0_col3" class="data row0 col3" >0.7285</td>
#       <td id="T_0d919_row0_col4" class="data row0 col4" >0.7262</td>
#       <td id="T_0d919_row0_col5" class="data row0 col5" >0.7094</td>
#       <td id="T_0d919_row0_col6" class="data row0 col6" >0.5982</td>
#       <td id="T_0d919_row0_col7" class="data row0 col7" >0.6104</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e546e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e546e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e546e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e546e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e546e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e546e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e546e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e546e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e546e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e546e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e546e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e546e_row0_col1" class="data row0 col1" >0.7285</td>
#       <td id="T_e546e_row0_col2" class="data row0 col2" >0.8937</td>
#       <td id="T_e546e_row0_col3" class="data row0 col3" >0.7285</td>
#       <td id="T_e546e_row0_col4" class="data row0 col4" >0.7262</td>
#       <td id="T_e546e_row0_col5" class="data row0 col5" >0.7094</td>
#       <td id="T_e546e_row0_col6" class="data row0 col6" >0.5982</td>
#       <td id="T_e546e_row0_col7" class="data row0 col7" >0.6104</td>
#     </tr>
#   </tbody>
# </table>
#    총거래물량(kg)        평균가격(원)  총거래금액(원)  거래단위  등급명  prediction_label  \
# 0     1800.0   62366.667969  11226000  10.0    3                 3
# 1     3840.0   95000.000000  36480000  10.0    3                 3
# 2     1200.0   60900.000000   7308000  10.0    3                 3
# 3      600.0   61300.000000   3678000  10.0    3                 3
# 4     3520.0  152875.562500  26906100  20.0    0                 0
#
#    prediction_score_0  prediction_score_1  prediction_score_2  \
# 0              0.0541              0.0027              0.0384
# 1              0.0047              0.0004              0.0065
# 2              0.0420              0.0031              0.0443
# 3              0.0083              0.0076              0.0978
# 4              0.6484              0.0473              0.0297
#
#    prediction_score_3
# 0              0.9048
# 1              0.9884
# 2              0.9106
# 3              0.8864
# 4              0.2745

# %%
# functional API
save_model(best, 'my_best_apple')

# OOP API
s.save_model(best, 'my_best_apple')
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['총거래물량(kg)', '평균가격(원)', '총거래금액(원)',
#                                               '거래단위'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None, include=[],...
#                   LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, importance_type='split',
#                                  learning_rate=0.1, max_depth=-1,
#                                  min_child_samples=20, min_child_weight=0.001,
#                                  min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                  num_leaves=31, objective=None,
#                                  random_state=7095, reg_alpha=0.0,
#                                  reg_lambda=0.0, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  'my_best_apple.pkl')

# %%
# functional API
loaded_model = load_model('my_best_apple')
print(loaded_model)

# OOP API
loaded_model = s.load_model('my_best_apple')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\jhi08\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['총거래물량(kg)', '평균가격(원)', '총거래금액(원)',
#                                              '거래단위'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  Tra...
#                  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 random_state=7095, reg_alpha=0.0,
#                                 reg_lambda=0.0, subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\jhi08\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['총거래물량(kg)', '평균가격(원)', '총거래금액(원)',
#                                              '거래단위'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  Tra...
#                  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 random_state=7095, reg_alpha=0.0,
#                                 reg_lambda=0.0, subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)

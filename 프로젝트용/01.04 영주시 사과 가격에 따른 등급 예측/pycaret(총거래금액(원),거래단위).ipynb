# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
import seaborn as sns
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
import autokeras as ak
# Out:
# WARNING:tensorflow:From c:\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from sklearn import tree

# %%
df = pd.read_excel('./농넷_영주시_일별사과.xlsx')

# %%
from pycaret.classification import *

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

encoder.fit(df['등급명'])
df['등급명'] = encoder.transform(df['등급명'])
df
# Out:
#             DATE  거래단위        평균가격(원)  총거래물량(kg)  총거래금액(원)     시장명      법인명  \
# 0     2024-03-13  10.0   62366.666667     1800.0  11226000  서울가락도매     동화청과
# 1     2024-03-13  10.0   95000.000000     3840.0  36480000  서울가락도매     서울청과
# 2     2024-03-13  10.0   60900.000000     1200.0   7308000  수원도매시장     경기청과
# 3     2024-03-13  10.0   61300.000000      600.0   3678000  인천삼산도매     경인농산
# 4     2024-03-13  20.0  152875.568182     3520.0  26906100  안동도매시장     안동청과
# ...          ...   ...            ...        ...       ...     ...      ...
# 65184 2020-01-03  10.0   24833.333333     2400.0   5960000  서울가락도매  농협가락(공)
# 65185 2020-01-03  10.0   20000.000000      300.0    600000  서울가락도매  농협가락(공)
# 65186 2020-01-03  18.0   25200.000000     2700.0   3780000  구리도매시장  농협구리(공)
# 65187 2020-01-03  18.0   25200.000000     1620.0   2268000  구리도매시장  농협구리(공)
# 65188 2020-01-02  10.0   23825.000000     1200.0   2859000  광주서부도매  농협광주(공)
#
#       품목명   품종명   산지명 산지시군명  등급명
# 0      사과   미시마  경상북도   영주시    3
# 1      사과    후지  경상북도   영주시    3
# 2      사과   미얀마    경북   영주시    3
# 3      사과   미시마  경상북도   영주시    3
# 4      사과   미얀마    경북   영주시    0
# ...    ..   ...   ...   ...  ...
# 65184  사과   미안마    경북   영주시    3
# 65185  사과    후지    경북   영주시    3
# 65186  사과  기타사과    경북   영주시    3
# 65187  사과  기타사과    경북   영주시    3
# 65188  사과    후지    경북   영주시    3
#
# [65189 rows x 12 columns]

# %%
df_temp = df[['등급명', '총거래금액(원)','거래단위']]
df_temp
# Out:
#        등급명  총거래금액(원)  거래단위
# 0        3  11226000  10.0
# 1        3  36480000  10.0
# 2        3   7308000  10.0
# 3        3   3678000  10.0
# 4        0  26906100  20.0
# ...    ...       ...   ...
# 65184    3   5960000  10.0
# 65185    3    600000  10.0
# 65186    3   3780000  18.0
# 65187    3   2268000  18.0
# 65188    3   2859000  10.0
#
# [65189 rows x 3 columns]

# %%
df_temp.isnull().sum()
# Out:
# 등급명         0
# 총거래금액(원)    0
# 거래단위        0
# dtype: int64

# %%
import numpy as np
# scikit-learn에서 R의 MICE 패키지를 따라서 실험적으로 개발 중
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df_temp.isnull().sum()
# Out:
# 등급명         0
# 총거래금액(원)    0
# 거래단위        0
# dtype: int64

# %%
s = setup(df_temp, target = '등급명')
# Out:
# <style type="text/css">
# #T_dac1f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dac1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dac1f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dac1f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dac1f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dac1f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dac1f_row0_col1" class="data row0 col1" >7649</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dac1f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dac1f_row1_col1" class="data row1 col1" >등급명</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dac1f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_dac1f_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dac1f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_dac1f_row3_col1" class="data row3 col1" >(65189, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dac1f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_dac1f_row4_col1" class="data row4 col1" >(65189, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dac1f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_dac1f_row5_col1" class="data row5 col1" >(45632, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dac1f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_dac1f_row6_col1" class="data row6 col1" >(19557, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dac1f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_dac1f_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dac1f_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_dac1f_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dac1f_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_dac1f_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dac1f_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_dac1f_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dac1f_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_dac1f_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dac1f_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_dac1f_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dac1f_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_dac1f_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dac1f_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_dac1f_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dac1f_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_dac1f_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dac1f_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_dac1f_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dac1f_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_dac1f_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_dac1f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dac1f_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_dac1f_row18_col1" class="data row18 col1" >bef2</td>
#     </tr>
#   </tbody>
# </table>

# %%
#pycaret
from pycaret.regression import RegressionExperiment
s = RegressionExperiment()
s.setup(df_temp, target = '등급명')
# Out:
# <style type="text/css">
# #T_78588_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78588">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78588_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_78588_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78588_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78588_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_78588_row0_col1" class="data row0 col1" >2084</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78588_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_78588_row1_col1" class="data row1 col1" >등급명</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78588_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_78588_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78588_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_78588_row3_col1" class="data row3 col1" >(65189, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78588_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_78588_row4_col1" class="data row4 col1" >(65189, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78588_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_78588_row5_col1" class="data row5 col1" >(45632, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78588_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_78588_row6_col1" class="data row6 col1" >(19557, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78588_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_78588_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78588_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_78588_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78588_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_78588_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_78588_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_78588_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_78588_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_78588_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_78588_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_78588_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_78588_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_78588_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_78588_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_78588_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_78588_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_78588_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_78588_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_78588_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_78588_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_78588_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_78588_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_78588_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_78588_row18_col1" class="data row18 col1" >9103</td>
#     </tr>
#   </tbody>
# </table>

# %%
# functional API
best = compare_models()

# OOP API
best = s.compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             10:23:59
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_cb56a th {
#   text-align: left;
# }
# #T_cb56a_row0_col0, #T_cb56a_row0_col2, #T_cb56a_row0_col5, #T_cb56a_row0_col6, #T_cb56a_row1_col0, #T_cb56a_row1_col1, #T_cb56a_row1_col2, #T_cb56a_row1_col3, #T_cb56a_row1_col4, #T_cb56a_row1_col7, #T_cb56a_row2_col0, #T_cb56a_row2_col1, #T_cb56a_row2_col3, #T_cb56a_row2_col4, #T_cb56a_row2_col5, #T_cb56a_row2_col6, #T_cb56a_row2_col7, #T_cb56a_row3_col0, #T_cb56a_row3_col1, #T_cb56a_row3_col2, #T_cb56a_row3_col3, #T_cb56a_row3_col4, #T_cb56a_row3_col5, #T_cb56a_row3_col6, #T_cb56a_row3_col7, #T_cb56a_row4_col0, #T_cb56a_row4_col1, #T_cb56a_row4_col2, #T_cb56a_row4_col3, #T_cb56a_row4_col4, #T_cb56a_row4_col5, #T_cb56a_row4_col6, #T_cb56a_row4_col7, #T_cb56a_row5_col0, #T_cb56a_row5_col1, #T_cb56a_row5_col2, #T_cb56a_row5_col3, #T_cb56a_row5_col4, #T_cb56a_row5_col5, #T_cb56a_row5_col6, #T_cb56a_row5_col7, #T_cb56a_row6_col0, #T_cb56a_row6_col1, #T_cb56a_row6_col2, #T_cb56a_row6_col3, #T_cb56a_row6_col4, #T_cb56a_row6_col5, #T_cb56a_row6_col6, #T_cb56a_row6_col7, #T_cb56a_row7_col0, #T_cb56a_row7_col1, #T_cb56a_row7_col2, #T_cb56a_row7_col3, #T_cb56a_row7_col4, #T_cb56a_row7_col5, #T_cb56a_row7_col6, #T_cb56a_row7_col7, #T_cb56a_row8_col0, #T_cb56a_row8_col1, #T_cb56a_row8_col2, #T_cb56a_row8_col3, #T_cb56a_row8_col4, #T_cb56a_row8_col5, #T_cb56a_row8_col6, #T_cb56a_row8_col7, #T_cb56a_row9_col0, #T_cb56a_row9_col1, #T_cb56a_row9_col2, #T_cb56a_row9_col3, #T_cb56a_row9_col4, #T_cb56a_row9_col5, #T_cb56a_row9_col6, #T_cb56a_row9_col7, #T_cb56a_row10_col0, #T_cb56a_row10_col1, #T_cb56a_row10_col2, #T_cb56a_row10_col3, #T_cb56a_row10_col4, #T_cb56a_row10_col5, #T_cb56a_row10_col6, #T_cb56a_row10_col7, #T_cb56a_row11_col0, #T_cb56a_row11_col1, #T_cb56a_row11_col2, #T_cb56a_row11_col3, #T_cb56a_row11_col4, #T_cb56a_row11_col5, #T_cb56a_row11_col6, #T_cb56a_row11_col7, #T_cb56a_row12_col0, #T_cb56a_row12_col1, #T_cb56a_row12_col2, #T_cb56a_row12_col3, #T_cb56a_row12_col4, #T_cb56a_row12_col5, #T_cb56a_row12_col6, #T_cb56a_row12_col7, #T_cb56a_row13_col0, #T_cb56a_row13_col1, #T_cb56a_row13_col2, #T_cb56a_row13_col3, #T_cb56a_row13_col4, #T_cb56a_row13_col5, #T_cb56a_row13_col6, #T_cb56a_row13_col7, #T_cb56a_row14_col0, #T_cb56a_row14_col1, #T_cb56a_row14_col2, #T_cb56a_row14_col3, #T_cb56a_row14_col4, #T_cb56a_row14_col5, #T_cb56a_row14_col6, #T_cb56a_row14_col7 {
#   text-align: left;
# }
# #T_cb56a_row0_col1, #T_cb56a_row0_col3, #T_cb56a_row0_col4, #T_cb56a_row0_col7, #T_cb56a_row1_col5, #T_cb56a_row1_col6, #T_cb56a_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cb56a_row0_col8, #T_cb56a_row1_col8, #T_cb56a_row2_col8, #T_cb56a_row3_col8, #T_cb56a_row4_col8, #T_cb56a_row7_col8, #T_cb56a_row8_col8, #T_cb56a_row9_col8, #T_cb56a_row10_col8, #T_cb56a_row11_col8, #T_cb56a_row13_col8, #T_cb56a_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cb56a_row5_col8, #T_cb56a_row6_col8, #T_cb56a_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cb56a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb56a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cb56a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cb56a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cb56a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cb56a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cb56a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cb56a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cb56a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_cb56a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb56a_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_cb56a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cb56a_row0_col1" class="data row0 col1" >0.6936</td>
#       <td id="T_cb56a_row0_col2" class="data row0 col2" >0.8412</td>
#       <td id="T_cb56a_row0_col3" class="data row0 col3" >0.6936</td>
#       <td id="T_cb56a_row0_col4" class="data row0 col4" >0.6749</td>
#       <td id="T_cb56a_row0_col5" class="data row0 col5" >0.6451</td>
#       <td id="T_cb56a_row0_col6" class="data row0 col6" >0.5365</td>
#       <td id="T_cb56a_row0_col7" class="data row0 col7" >0.5633</td>
#       <td id="T_cb56a_row0_col8" class="data row0 col8" >0.5060</td>
#     </tr>
#     <tr>
#       <th id="T_cb56a_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_cb56a_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_cb56a_row1_col1" class="data row1 col1" >0.6934</td>
#       <td id="T_cb56a_row1_col2" class="data row1 col2" >0.8400</td>
#       <td id="T_cb56a_row1_col3" class="data row1 col3" >0.6934</td>
#       <td id="T_cb56a_row1_col4" class="data row1 col4" >0.6602</td>
#       <td id="T_cb56a_row1_col5" class="data row1 col5" >0.6456</td>
#       <td id="T_cb56a_row1_col6" class="data row1 col6" >0.5366</td>
#       <td id="T_cb56a_row1_col7" class="data row1 col7" >0.5631</td>
#       <td id="T_cb56a_row1_col8" class="data row1 col8" >0.2390</td>
#     </tr>
#     <tr>
#       <th id="T_cb56a_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_cb56a_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_cb56a_row2_col1" class="data row2 col1" >0.6931</td>
#       <td id="T_cb56a_row2_col2" class="data row2 col2" >0.8434</td>
#       <td id="T_cb56a_row2_col3" class="data row2 col3" >0.6931</td>
#       <td id="T_cb56a_row2_col4" class="data row2 col4" >0.6659</td>
#       <td id="T_cb56a_row2_col5" class="data row2 col5" >0.6444</td>
#       <td id="T_cb56a_row2_col6" class="data row2 col6" >0.5357</td>
#       <td id="T_cb56a_row2_col7" class="data row2 col7" >0.5628</td>
#       <td id="T_cb56a_row2_col8" class="data row2 col8" >1.1790</td>
#     </tr>
#     <tr>
#       <th id="T_cb56a_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_cb56a_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_cb56a_row3_col1" class="data row3 col1" >0.6630</td>
#       <td id="T_cb56a_row3_col2" class="data row3 col2" >0.8014</td>
#       <td id="T_cb56a_row3_col3" class="data row3 col3" >0.6630</td>
#       <td id="T_cb56a_row3_col4" class="data row3 col4" >0.5793</td>
#       <td id="T_cb56a_row3_col5" class="data row3 col5" >0.5757</td>
#       <td id="T_cb56a_row3_col6" class="data row3 col6" >0.4793</td>
#       <td id="T_cb56a_row3_col7" class="data row3 col7" >0.5153</td>
#       <td id="T_cb56a_row3_col8" class="data row3 col8" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_cb56a_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_cb56a_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_cb56a_row4_col1" class="data row4 col1" >0.6611</td>
#       <td id="T_cb56a_row4_col2" class="data row4 col2" >0.8286</td>
#       <td id="T_cb56a_row4_col3" class="data row4 col3" >0.6611</td>
#       <td id="T_cb56a_row4_col4" class="data row4 col4" >0.6297</td>
#       <td id="T_cb56a_row4_col5" class="data row4 col5" >0.5717</td>
#       <td id="T_cb56a_row4_col6" class="data row4 col6" >0.4758</td>
#       <td id="T_cb56a_row4_col7" class="data row4 col7" >0.5158</td>
#       <td id="T_cb56a_row4_col8" class="data row4 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_cb56a_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_cb56a_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_cb56a_row5_col1" class="data row5 col1" >0.6559</td>
#       <td id="T_cb56a_row5_col2" class="data row5 col2" >0.8048</td>
#       <td id="T_cb56a_row5_col3" class="data row5 col3" >0.6559</td>
#       <td id="T_cb56a_row5_col4" class="data row5 col4" >0.5526</td
# <style type="text/css">
# #T_05463 th {
#   text-align: left;
# }
# #T_05463_row0_col0, #T_05463_row0_col1, #T_05463_row0_col6, #T_05463_row1_col0, #T_05463_row1_col2, #T_05463_row1_col3, #T_05463_row1_col4, #T_05463_row1_col5, #T_05463_row1_col6, #T_05463_row2_col0, #T_05463_row2_col1, #T_05463_row2_col2, #T_05463_row2_col3, #T_05463_row2_col4, #T_05463_row2_col5, #T_05463_row2_col6, #T_05463_row3_col0, #T_05463_row3_col1, #T_05463_row3_col2, #T_05463_row3_col3, #T_05463_row3_col4, #T_05463_row3_col5, #T_05463_row4_col0, #T_05463_row4_col1, #T_05463_row4_col2, #T_05463_row4_col3, #T_05463_row4_col4, #T_05463_row4_col5, #T_05463_row4_col6, #T_05463_row5_col0, #T_05463_row5_col1, #T_05463_row5_col2, #T_05463_row5_col3, #T_05463_row5_col4, #T_05463_row5_col5, #T_05463_row5_col6, #T_05463_row6_col0, #T_05463_row6_col1, #T_05463_row6_col2, #T_05463_row6_col3, #T_05463_row6_col4, #T_05463_row6_col5, #T_05463_row6_col6, #T_05463_row7_col0, #T_05463_row7_col1, #T_05463_row7_col2, #T_05463_row7_col3, #T_05463_row7_col4, #T_05463_row7_col5, #T_05463_row7_col6, #T_05463_row8_col0, #T_05463_row8_col1, #T_05463_row8_col2, #T_05463_row8_col3, #T_05463_row8_col4, #T_05463_row8_col5, #T_05463_row8_col6, #T_05463_row9_col0, #T_05463_row9_col1, #T_05463_row9_col2, #T_05463_row9_col3, #T_05463_row9_col4, #T_05463_row9_col5, #T_05463_row9_col6, #T_05463_row10_col0, #T_05463_row10_col1, #T_05463_row10_col2, #T_05463_row10_col3, #T_05463_row10_col4, #T_05463_row10_col5, #T_05463_row10_col6, #T_05463_row11_col0, #T_05463_row11_col1, #T_05463_row11_col2, #T_05463_row11_col3, #T_05463_row11_col4, #T_05463_row11_col5, #T_05463_row11_col6, #T_05463_row12_col0, #T_05463_row12_col1, #T_05463_row12_col2, #T_05463_row12_col3, #T_05463_row12_col4, #T_05463_row12_col5, #T_05463_row12_col6, #T_05463_row13_col0, #T_05463_row13_col1, #T_05463_row13_col2, #T_05463_row13_col3, #T_05463_row13_col4, #T_05463_row13_col5, #T_05463_row13_col6, #T_05463_row14_col0, #T_05463_row14_col1, #T_05463_row14_col2, #T_05463_row14_col3, #T_05463_row14_col4, #T_05463_row14_col5, #T_05463_row14_col6, #T_05463_row15_col0, #T_05463_row15_col1, #T_05463_row15_col2, #T_05463_row15_col3, #T_05463_row15_col4, #T_05463_row15_col5, #T_05463_row15_col6, #T_05463_row16_col0, #T_05463_row16_col1, #T_05463_row16_col2, #T_05463_row16_col3, #T_05463_row16_col4, #T_05463_row16_col5, #T_05463_row16_col6, #T_05463_row17_col0, #T_05463_row17_col1, #T_05463_row17_col2, #T_05463_row17_col3, #T_05463_row17_col4, #T_05463_row17_col5, #T_05463_row17_col6, #T_05463_row18_col0, #T_05463_row18_col1, #T_05463_row18_col2, #T_05463_row18_col3, #T_05463_row18_col4, #T_05463_row18_col5, #T_05463_row18_col6 {
#   text-align: left;
# }
# #T_05463_row0_col2, #T_05463_row0_col3, #T_05463_row0_col4, #T_05463_row0_col5, #T_05463_row1_col1, #T_05463_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_05463_row0_col7, #T_05463_row1_col7, #T_05463_row2_col7, #T_05463_row3_col7, #T_05463_row4_col7, #T_05463_row5_col7, #T_05463_row7_col7, #T_05463_row8_col7, #T_05463_row9_col7, #T_05463_row10_col7, #T_05463_row11_col7, #T_05463_row12_col7, #T_05463_row13_col7, #T_05463_row14_col7, #T_05463_row15_col7, #T_05463_row16_col7, #T_05463_row17_col7, #T_05463_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_05463_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_05463">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05463_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_05463_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_05463_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_05463_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_05463_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_05463_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_05463_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_05463_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05463_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_05463_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_05463_row0_col1" class="data row0 col1" >0.6258</td>
#       <td id="T_05463_row0_col2" class="data row0 col2" >0.6956</td>
#       <td id="T_05463_row0_col3" class="data row0 col3" >0.8340</td>
#       <td id="T_05463_row0_col4" class="data row0 col4" >0.5843</td>
#       <td id="T_05463_row0_col5" class="data row0 col5" >0.4227</td>
#       <td id="T_05463_row0_col6" class="data row0 col6" >0.2572</td>
#       <td id="T_05463_row0_col7" class="data row0 col7" >0.3230</td>
#     </tr>
#     <tr>
#       <th id="T_05463_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_05463_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_05463_row1_col1" class="data row1 col1" >0.6233</td>
#       <td id="T_05463_row1_col2" class="data row1 col2" >0.6972</td>
#       <td id="T_05463_row1_col3" class="data row1 col3" >0.8349</td>
#       <td id="T_05463_row1_col4" class="data row1 col4" >0.5833</td>
#       <td id="T_05463_row1_col5" class="data row1 col5" >0.4228</td>
#       <td id="T_05463_row1_col6" class="data row1 col6" >0.2572</td>
#       <td id="T_05463_row1_col7" class="data row1 col7" >0.1330</td>
#     </tr>
#     <tr>
#       <th id="T_05463_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_05463_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_05463_row2_col1" class="data row2 col1" >0.6235</td>
#       <td id="T_05463_row2_col2" class="data row2 col2" >0.7020</td>
#       <td id="T_05463_row2_col3" class="data row2 col3" >0.8378</td>
#       <td id="T_05463_row2_col4" class="data row2 col4" >0.5805</td>
#       <td id="T_05463_row2_col5" class="data row2 col5" >0.4237</td>
#       <td id="T_05463_row2_col6" class="data row2 col6" >0.2581</td>
#       <td id="T_05463_row2_col7" class="data row2 col7" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_05463_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_05463_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_05463_row3_col1" class="data row3 col1" >0.6913</td>
#       <td id="T_05463_row3_col2" class="data row3 col2" >0.7339</td>
#       <td id="T_05463_row3_col3" class="data row3 col3" >0.8567</td>
#       <td id="T_05463_row3_col4" class="data row3 col4" >0.5614</td>
#       <td id="T_05463_row3_col5" class="data row3 col5" >0.4533</td>
#       <td id="T_05463_row3_col6" class="data row3 col6" >0.2371</td>
#       <td id="T_05463_row3_col7" class="data row3 col7" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_05463_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_05463_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_05463_row4_col1" class="data row4 col1" >0.7452</td>
#       <td id="T_05463_row4_col2" class="data row4 col2" >0.7942</td>
#       <td id="T_05463_row4_col3" class="data row4 col3" >0.8911</td>
#       <td id="T_05463_row4_col4" class="data row4 col4" >0.5254</td>
#       <td id="T_05463_row4_col5" class="data row4 col5" >0.4424</td>
#       <td id="T_05463_row4_col6" class="data row4 col6" >0.3009</td>
#       <td id="T_05463_row4_col7" class="data row4 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_05463_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_05463_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_05463_row5_col1" class="data row5 col1" >0.7452</td>
#       <td id="T_05463_row5_col2" class="data row5 col2" >0.7942</td>
#       <td id="T_05463_row5_col3" class="data row5 col3" >0.8911</td>
#       <td id="T_05463_row5_col4" class="data row5 col4" >0.5254</td>
#       <td id="T_05463_row5_col5" class="data row5 col5" >0.4424</td>
#       <td id="T_0546

# %%
print(best)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=8410, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
# functional API
evaluate_model(best)

# OOP API
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# functional API
plot_model(best, plot = 'auc')

# OOP API
s.plot_model(best, plot = 'auc')

# %%
# functional API
plot_model(best, plot = 'confusion_matrix')

# OOP API
s.plot_model(best, plot = 'confusion_matrix')

# %%
# functional API
predict_model(best)

# OOP API
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8185a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8185a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8185a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8185a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8185a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8185a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8185a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8185a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8185a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8185a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8185a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8185a_row0_col1" class="data row0 col1" >0.7270</td>
#       <td id="T_8185a_row0_col2" class="data row0 col2" >0.8943</td>
#       <td id="T_8185a_row0_col3" class="data row0 col3" >0.7270</td>
#       <td id="T_8185a_row0_col4" class="data row0 col4" >0.7248</td>
#       <td id="T_8185a_row0_col5" class="data row0 col5" >0.7078</td>
#       <td id="T_8185a_row0_col6" class="data row0 col6" >0.5960</td>
#       <td id="T_8185a_row0_col7" class="data row0 col7" >0.6082</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3a804">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a804_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3a804_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3a804_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3a804_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3a804_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3a804_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3a804_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3a804_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a804_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a804_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3a804_row0_col1" class="data row0 col1" >0.7174</td>
#       <td id="T_3a804_row0_col2" class="data row0 col2" >0.8799</td>
#       <td id="T_3a804_row0_col3" class="data row0 col3" >0.7174</td>
#       <td id="T_3a804_row0_col4" class="data row0 col4" >0.7125</td>
#       <td id="T_3a804_row0_col5" class="data row0 col5" >0.6981</td>
#       <td id="T_3a804_row0_col6" class="data row0 col6" >0.5824</td>
#       <td id="T_3a804_row0_col7" class="data row0 col7" >0.5941</td>
#     </tr>
#   </tbody>
# </table>
#        총거래물량(kg)       평균가격(원)  총거래금액(원)  거래단위  등급명  prediction_label  \
# 60417      140.0  30857.142578    432000  10.0    2                 3
# 16400      840.0  43142.855469   1812000  20.0    0                 0
# 26561     2400.0  26206.250000   6289500  10.0    3                 3
# 35240     1670.0  33526.945312   5599000  10.0    3                 3
# 34256      600.0  24833.333984   1490000  10.0    3                 3
# ...          ...           ...       ...   ...  ...               ...
# 22967      300.0  28000.000000    420000  20.0    0                 0
# 40010       20.0  21500.000000     21500  20.0    0                 0
# 27597     3150.0   6320.000000   7963200   2.5    3                 3
# 64021      340.0   5426.470703    184500  10.0    2                 2
# 32964      700.0  54662.855469   1913200  20.0    0                 0
#
#        prediction_score
# 60417            0.5576
# 16400            0.4813
# 26561            0.9470
# 35240            0.9451
# 34256            0.7997
# ...                 ...
# 22967            0.5569
# 40010            0.8151
# 27597            0.9075
# 64021            0.6624
# 32964            0.5547
#
# [19557 rows x 7 columns]

# %%
# functional API
predictions = predict_model(best, data=df_temp)
predictions.head()

# OOP API
predictions = s.predict_model(best, data=df_temp)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b591">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b591_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0b591_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0b591_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0b591_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0b591_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0b591_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0b591_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0b591_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b591_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b591_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0b591_row0_col1" class="data row0 col1" >0.7281</td>
#       <td id="T_0b591_row0_col2" class="data row0 col2" >0.8941</td>
#       <td id="T_0b591_row0_col3" class="data row0 col3" >0.7281</td>
#       <td id="T_0b591_row0_col4" class="data row0 col4" >0.7269</td>
#       <td id="T_0b591_row0_col5" class="data row0 col5" >0.7096</td>
#       <td id="T_0b591_row0_col6" class="data row0 col6" >0.5979</td>
#       <td id="T_0b591_row0_col7" class="data row0 col7" >0.6102</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_019c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_019c0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_019c0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_019c0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_019c0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_019c0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_019c0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_019c0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_019c0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_019c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_019c0_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_019c0_row0_col1" class="data row0 col1" >0.7281</td>
#       <td id="T_019c0_row0_col2" class="data row0 col2" >0.8941</td>
#       <td id="T_019c0_row0_col3" class="data row0 col3" >0.7281</td>
#       <td id="T_019c0_row0_col4" class="data row0 col4" >0.7269</td>
#       <td id="T_019c0_row0_col5" class="data row0 col5" >0.7096</td>
#       <td id="T_019c0_row0_col6" class="data row0 col6" >0.5979</td>
#       <td id="T_019c0_row0_col7" class="data row0 col7" >0.6102</td>
#     </tr>
#   </tbody>
# </table>
#    총거래물량(kg)        평균가격(원)  총거래금액(원)  거래단위  등급명  prediction_label  \
# 0     1800.0   62366.667969  11226000  10.0    3                 3
# 1     3840.0   95000.000000  36480000  10.0    3                 3
# 2     1200.0   60900.000000   7308000  10.0    3                 3
# 3      600.0   61300.000000   3678000  10.0    3                 3
# 4     3520.0  152875.562500  26906100  20.0    0                 0
#
#    prediction_score
# 0            0.9176
# 1            0.9817
# 2            0.9206
# 3            0.8524
# 4            0.6379

# %%
# functional API
predictions = predict_model(best, data=df_temp, raw_score=True)
predictions.head()

# OOP API
predictions = s.predict_model(best, data=df_temp, raw_score=True)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7e7e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e7e5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7e7e5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7e7e5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7e7e5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7e7e5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7e7e5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7e7e5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7e7e5_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e7e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e7e5_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7e7e5_row0_col1" class="data row0 col1" >0.7281</td>
#       <td id="T_7e7e5_row0_col2" class="data row0 col2" >0.8941</td>
#       <td id="T_7e7e5_row0_col3" class="data row0 col3" >0.7281</td>
#       <td id="T_7e7e5_row0_col4" class="data row0 col4" >0.7269</td>
#       <td id="T_7e7e5_row0_col5" class="data row0 col5" >0.7096</td>
#       <td id="T_7e7e5_row0_col6" class="data row0 col6" >0.5979</td>
#       <td id="T_7e7e5_row0_col7" class="data row0 col7" >0.6102</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_8a375">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a375_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8a375_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8a375_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8a375_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8a375_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8a375_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8a375_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8a375_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a375_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a375_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8a375_row0_col1" class="data row0 col1" >0.7281</td>
#       <td id="T_8a375_row0_col2" class="data row0 col2" >0.8941</td>
#       <td id="T_8a375_row0_col3" class="data row0 col3" >0.7281</td>
#       <td id="T_8a375_row0_col4" class="data row0 col4" >0.7269</td>
#       <td id="T_8a375_row0_col5" class="data row0 col5" >0.7096</td>
#       <td id="T_8a375_row0_col6" class="data row0 col6" >0.5979</td>
#       <td id="T_8a375_row0_col7" class="data row0 col7" >0.6102</td>
#     </tr>
#   </tbody>
# </table>
#    총거래물량(kg)        평균가격(원)  총거래금액(원)  거래단위  등급명  prediction_label  \
# 0     1800.0   62366.667969  11226000  10.0    3                 3
# 1     3840.0   95000.000000  36480000  10.0    3                 3
# 2     1200.0   60900.000000   7308000  10.0    3                 3
# 3      600.0   61300.000000   3678000  10.0    3                 3
# 4     3520.0  152875.562500  26906100  20.0    0                 0
#
#    prediction_score_0  prediction_score_1  prediction_score_2  \
# 0              0.0371              0.0030              0.0423
# 1              0.0128              0.0006              0.0050
# 2              0.0355              0.0034              0.0405
# 3              0.0157              0.0085              0.1234
# 4              0.6379              0.0626              0.0231
#
#    prediction_score_3
# 0              0.9176
# 1              0.9817
# 2              0.9206
# 3              0.8524
# 4              0.2763

# %%
# functional API
save_model(best, 'my_best_apple')

# OOP API
s.save_model(best, 'my_best_apple')
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['총거래물량(kg)', '평균가격(원)', '총거래금액(원)',
#                                               '거래단위'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None, include=[],...
#                   LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, importance_type='split',
#                                  learning_rate=0.1, max_depth=-1,
#                                  min_child_samples=20, min_child_weight=0.001,
#                                  min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                  num_leaves=31, objective=None,
#                                  random_state=8410, reg_alpha=0.0,
#                                  reg_lambda=0.0, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  'my_best_apple.pkl')

# %%
# functional API
loaded_model = load_model('my_best_apple')
print(loaded_model)

# OOP API
loaded_model = s.load_model('my_best_apple')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\jhi08\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['총거래물량(kg)', '평균가격(원)', '총거래금액(원)',
#                                              '거래단위'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  Tra...
#                  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 random_state=8410, reg_alpha=0.0,
#                                 reg_lambda=0.0, subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\jhi08\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['총거래물량(kg)', '평균가격(원)', '총거래금액(원)',
#                                              '거래단위'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  Tra...
#                  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 random_state=8410, reg_alpha=0.0,
#                                 reg_lambda=0.0, subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)

# %%
#automl framework
from pycaret.regression import *
s = setup(df_temp, target = '등급명')
# Out:
# <style type="text/css">
# #T_5259e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5259e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5259e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5259e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5259e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5259e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5259e_row0_col1" class="data row0 col1" >3697</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5259e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5259e_row1_col1" class="data row1 col1" >등급명</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5259e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5259e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5259e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5259e_row3_col1" class="data row3 col1" >(65189, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5259e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5259e_row4_col1" class="data row4 col1" >(65189, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5259e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5259e_row5_col1" class="data row5 col1" >(45632, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5259e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5259e_row6_col1" class="data row6 col1" >(19557, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5259e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5259e_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5259e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_5259e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5259e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_5259e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5259e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_5259e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5259e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_5259e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5259e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_5259e_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5259e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_5259e_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5259e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_5259e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5259e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_5259e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5259e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5259e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5259e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5259e_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5259e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5259e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5259e_row18_col1" class="data row18 col1" >33d8</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.regression import RegressionExperiment
s = RegressionExperiment()
s.setup(df_temp, target = '등급명')
# Out:
# <style type="text/css">
# #T_cce60_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cce60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cce60_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cce60_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cce60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cce60_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cce60_row0_col1" class="data row0 col1" >6487</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cce60_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cce60_row1_col1" class="data row1 col1" >등급명</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cce60_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cce60_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cce60_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cce60_row3_col1" class="data row3 col1" >(65189, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cce60_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cce60_row4_col1" class="data row4 col1" >(65189, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cce60_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cce60_row5_col1" class="data row5 col1" >(45632, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cce60_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cce60_row6_col1" class="data row6 col1" >(19557, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cce60_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_cce60_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cce60_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_cce60_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cce60_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_cce60_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cce60_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_cce60_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cce60_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_cce60_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cce60_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_cce60_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cce60_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_cce60_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cce60_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_cce60_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cce60_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_cce60_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cce60_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_cce60_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cce60_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_cce60_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cce60_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cce60_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_cce60_row18_col1" class="data row18 col1" >b711</td>
#     </tr>
#   </tbody>
# </table>

# %%
# functional API
best = compare_models()

# OOP API
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_6a148 th {
#   text-align: left;
# }
# #T_6a148_row0_col0, #T_6a148_row0_col1, #T_6a148_row0_col5, #T_6a148_row0_col6, #T_6a148_row1_col0, #T_6a148_row1_col2, #T_6a148_row1_col3, #T_6a148_row1_col4, #T_6a148_row1_col6, #T_6a148_row2_col0, #T_6a148_row2_col1, #T_6a148_row2_col2, #T_6a148_row2_col3, #T_6a148_row2_col4, #T_6a148_row2_col5, #T_6a148_row2_col6, #T_6a148_row3_col0, #T_6a148_row3_col1, #T_6a148_row3_col2, #T_6a148_row3_col3, #T_6a148_row3_col4, #T_6a148_row3_col5, #T_6a148_row4_col0, #T_6a148_row4_col1, #T_6a148_row4_col2, #T_6a148_row4_col3, #T_6a148_row4_col4, #T_6a148_row4_col5, #T_6a148_row4_col6, #T_6a148_row5_col0, #T_6a148_row5_col1, #T_6a148_row5_col2, #T_6a148_row5_col3, #T_6a148_row5_col4, #T_6a148_row5_col5, #T_6a148_row5_col6, #T_6a148_row6_col0, #T_6a148_row6_col1, #T_6a148_row6_col2, #T_6a148_row6_col3, #T_6a148_row6_col4, #T_6a148_row6_col5, #T_6a148_row6_col6, #T_6a148_row7_col0, #T_6a148_row7_col1, #T_6a148_row7_col2, #T_6a148_row7_col3, #T_6a148_row7_col4, #T_6a148_row7_col5, #T_6a148_row7_col6, #T_6a148_row8_col0, #T_6a148_row8_col1, #T_6a148_row8_col2, #T_6a148_row8_col3, #T_6a148_row8_col4, #T_6a148_row8_col5, #T_6a148_row8_col6, #T_6a148_row9_col0, #T_6a148_row9_col1, #T_6a148_row9_col2, #T_6a148_row9_col3, #T_6a148_row9_col4, #T_6a148_row9_col5, #T_6a148_row9_col6, #T_6a148_row10_col0, #T_6a148_row10_col1, #T_6a148_row10_col2, #T_6a148_row10_col3, #T_6a148_row10_col4, #T_6a148_row10_col5, #T_6a148_row10_col6, #T_6a148_row11_col0, #T_6a148_row11_col1, #T_6a148_row11_col2, #T_6a148_row11_col3, #T_6a148_row11_col4, #T_6a148_row11_col5, #T_6a148_row11_col6, #T_6a148_row12_col0, #T_6a148_row12_col1, #T_6a148_row12_col2, #T_6a148_row12_col3, #T_6a148_row12_col4, #T_6a148_row12_col5, #T_6a148_row12_col6, #T_6a148_row13_col0, #T_6a148_row13_col1, #T_6a148_row13_col2, #T_6a148_row13_col3, #T_6a148_row13_col4, #T_6a148_row13_col5, #T_6a148_row13_col6, #T_6a148_row14_col0, #T_6a148_row14_col1, #T_6a148_row14_col2, #T_6a148_row14_col3, #T_6a148_row14_col4, #T_6a148_row14_col5, #T_6a148_row14_col6, #T_6a148_row15_col0, #T_6a148_row15_col1, #T_6a148_row15_col2, #T_6a148_row15_col3, #T_6a148_row15_col4, #T_6a148_row15_col5, #T_6a148_row15_col6, #T_6a148_row16_col0, #T_6a148_row16_col1, #T_6a148_row16_col2, #T_6a148_row16_col3, #T_6a148_row16_col4, #T_6a148_row16_col5, #T_6a148_row16_col6, #T_6a148_row17_col0, #T_6a148_row17_col1, #T_6a148_row17_col2, #T_6a148_row17_col3, #T_6a148_row17_col4, #T_6a148_row17_col5, #T_6a148_row17_col6, #T_6a148_row18_col0, #T_6a148_row18_col1, #T_6a148_row18_col2, #T_6a148_row18_col3, #T_6a148_row18_col4, #T_6a148_row18_col5, #T_6a148_row18_col6 {
#   text-align: left;
# }
# #T_6a148_row0_col2, #T_6a148_row0_col3, #T_6a148_row0_col4, #T_6a148_row1_col1, #T_6a148_row1_col5, #T_6a148_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6a148_row0_col7, #T_6a148_row1_col7, #T_6a148_row2_col7, #T_6a148_row3_col7, #T_6a148_row4_col7, #T_6a148_row5_col7, #T_6a148_row8_col7, #T_6a148_row10_col7, #T_6a148_row11_col7, #T_6a148_row12_col7, #T_6a148_row13_col7, #T_6a148_row14_col7, #T_6a148_row15_col7, #T_6a148_row17_col7, #T_6a148_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6a148_row6_col7, #T_6a148_row7_col7, #T_6a148_row9_col7, #T_6a148_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6a148">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a148_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6a148_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6a148_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6a148_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6a148_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6a148_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6a148_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6a148_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a148_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_6a148_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6a148_row0_col1" class="data row0 col1" >0.6000</td>
#       <td id="T_6a148_row0_col2" class="data row0 col2" >0.6666</td>
#       <td id="T_6a148_row0_col3" class="data row0 col3" >0.8163</td>
#       <td id="T_6a148_row0_col4" class="data row0 col4" >0.6018</td>
#       <td id="T_6a148_row0_col5" class="data row0 col5" >0.4107</td>
#       <td id="T_6a148_row0_col6" class="data row0 col6" >0.2491</td>
#       <td id="T_6a148_row0_col7" class="data row0 col7" >0.4460</td>
#     </tr>
#     <tr>
#       <th id="T_6a148_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_6a148_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6a148_row1_col1" class="data row1 col1" >0.5937</td>
#       <td id="T_6a148_row1_col2" class="data row1 col2" >0.6684</td>
#       <td id="T_6a148_row1_col3" class="data row1 col3" >0.8174</td>
#       <td id="T_6a148_row1_col4" class="data row1 col4" >0.6007</td>
#       <td id="T_6a148_row1_col5" class="data row1 col5" >0.4105</td>
#       <td id="T_6a148_row1_col6" class="data row1 col6" >0.2471</td>
#       <td id="T_6a148_row1_col7" class="data row1 col7" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_6a148_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_6a148_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6a148_row2_col1" class="data row2 col1" >0.5960</td>
#       <td id="T_6a148_row2_col2" class="data row2 col2" >0.6879</td>
#       <td id="T_6a148_row2_col3" class="data row2 col3" >0.8292</td>
#       <td id="T_6a148_row2_col4" class="data row2 col4" >0.5891</td>
#       <td id="T_6a148_row2_col5" class="data row2 col5" >0.4155</td>
#       <td id="T_6a148_row2_col6" class="data row2 col6" >0.2521</td>
#       <td id="T_6a148_row2_col7" class="data row2 col7" >0.2040</td>
#     </tr>
#     <tr>
#       <th id="T_6a148_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_6a148_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_6a148_row3_col1" class="data row3 col1" >0.6904</td>
#       <td id="T_6a148_row3_col2" class="data row3 col2" >0.7250</td>
#       <td id="T_6a148_row3_col3" class="data row3 col3" >0.8514</td>
#       <td id="T_6a148_row3_col4" class="data row3 col4" >0.5669</td>
#       <td id="T_6a148_row3_col5" class="data row3 col5" >0.4511</td>
#       <td id="T_6a148_row3_col6" class="data row3 col6" >0.2386</td>
#       <td id="T_6a148_row3_col7" class="data row3 col7" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_6a148_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_6a148_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_6a148_row4_col1" class="data row4 col1" >0.7257</td>
#       <td id="T_6a148_row4_col2" class="data row4 col2" >0.7686</td>
#       <td id="T_6a148_row4_col3" class="data row4 col3" >0.8766</td>
#       <td id="T_6a148_row4_col4" class="data row4 col4" >0.5408</td>
#       <td id="T_6a148_row4_col5" class="data row4 col5" >0.4349</td>
#       <td id="T_6a148_row4_col6" class="data row4 col6" >0.3043</td>
#       <td id="T_6a148_row4_col7" class="data row4 col7" >0.6210</td>
#     </tr>
#     <tr>
#       <th id="T_6a148_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_6a148_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_6a148_row5_col1" class="data row5 col1" >0.7257</td>
#       <td id="T_6a148_row5_col2" class="data row5 col2" >0.7686</td>
#       <td id="T_6a148_row5_col3" class="data row5 col3" >0.8766</td>
#       <td id="T_6a148_row5_col4" class="data row5 col4" >0.5408</td>
#       <td id="T_6a148_row5_col5" class="data row5 col5" >0.4349</td>
#       <td id="T_6a14
# <style type="text/css">
# #T_ebce9 th {
#   text-align: left;
# }
# #T_ebce9_row0_col0, #T_ebce9_row0_col1, #T_ebce9_row0_col5, #T_ebce9_row0_col6, #T_ebce9_row1_col0, #T_ebce9_row1_col2, #T_ebce9_row1_col3, #T_ebce9_row1_col4, #T_ebce9_row1_col6, #T_ebce9_row2_col0, #T_ebce9_row2_col1, #T_ebce9_row2_col2, #T_ebce9_row2_col3, #T_ebce9_row2_col4, #T_ebce9_row2_col5, #T_ebce9_row2_col6, #T_ebce9_row3_col0, #T_ebce9_row3_col1, #T_ebce9_row3_col2, #T_ebce9_row3_col3, #T_ebce9_row3_col4, #T_ebce9_row3_col5, #T_ebce9_row4_col0, #T_ebce9_row4_col1, #T_ebce9_row4_col2, #T_ebce9_row4_col3, #T_ebce9_row4_col4, #T_ebce9_row4_col5, #T_ebce9_row4_col6, #T_ebce9_row5_col0, #T_ebce9_row5_col1, #T_ebce9_row5_col2, #T_ebce9_row5_col3, #T_ebce9_row5_col4, #T_ebce9_row5_col5, #T_ebce9_row5_col6, #T_ebce9_row6_col0, #T_ebce9_row6_col1, #T_ebce9_row6_col2, #T_ebce9_row6_col3, #T_ebce9_row6_col4, #T_ebce9_row6_col5, #T_ebce9_row6_col6, #T_ebce9_row7_col0, #T_ebce9_row7_col1, #T_ebce9_row7_col2, #T_ebce9_row7_col3, #T_ebce9_row7_col4, #T_ebce9_row7_col5, #T_ebce9_row7_col6, #T_ebce9_row8_col0, #T_ebce9_row8_col1, #T_ebce9_row8_col2, #T_ebce9_row8_col3, #T_ebce9_row8_col4, #T_ebce9_row8_col5, #T_ebce9_row8_col6, #T_ebce9_row9_col0, #T_ebce9_row9_col1, #T_ebce9_row9_col2, #T_ebce9_row9_col3, #T_ebce9_row9_col4, #T_ebce9_row9_col5, #T_ebce9_row9_col6, #T_ebce9_row10_col0, #T_ebce9_row10_col1, #T_ebce9_row10_col2, #T_ebce9_row10_col3, #T_ebce9_row10_col4, #T_ebce9_row10_col5, #T_ebce9_row10_col6, #T_ebce9_row11_col0, #T_ebce9_row11_col1, #T_ebce9_row11_col2, #T_ebce9_row11_col3, #T_ebce9_row11_col4, #T_ebce9_row11_col5, #T_ebce9_row11_col6, #T_ebce9_row12_col0, #T_ebce9_row12_col1, #T_ebce9_row12_col2, #T_ebce9_row12_col3, #T_ebce9_row12_col4, #T_ebce9_row12_col5, #T_ebce9_row12_col6, #T_ebce9_row13_col0, #T_ebce9_row13_col1, #T_ebce9_row13_col2, #T_ebce9_row13_col3, #T_ebce9_row13_col4, #T_ebce9_row13_col5, #T_ebce9_row13_col6, #T_ebce9_row14_col0, #T_ebce9_row14_col1, #T_ebce9_row14_col2, #T_ebce9_row14_col3, #T_ebce9_row14_col4, #T_ebce9_row14_col5, #T_ebce9_row14_col6, #T_ebce9_row15_col0, #T_ebce9_row15_col1, #T_ebce9_row15_col2, #T_ebce9_row15_col3, #T_ebce9_row15_col4, #T_ebce9_row15_col5, #T_ebce9_row15_col6, #T_ebce9_row16_col0, #T_ebce9_row16_col1, #T_ebce9_row16_col2, #T_ebce9_row16_col3, #T_ebce9_row16_col4, #T_ebce9_row16_col5, #T_ebce9_row16_col6, #T_ebce9_row17_col0, #T_ebce9_row17_col1, #T_ebce9_row17_col2, #T_ebce9_row17_col3, #T_ebce9_row17_col4, #T_ebce9_row17_col5, #T_ebce9_row17_col6, #T_ebce9_row18_col0, #T_ebce9_row18_col1, #T_ebce9_row18_col2, #T_ebce9_row18_col3, #T_ebce9_row18_col4, #T_ebce9_row18_col5, #T_ebce9_row18_col6 {
#   text-align: left;
# }
# #T_ebce9_row0_col2, #T_ebce9_row0_col3, #T_ebce9_row0_col4, #T_ebce9_row1_col1, #T_ebce9_row1_col5, #T_ebce9_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ebce9_row0_col7, #T_ebce9_row1_col7, #T_ebce9_row2_col7, #T_ebce9_row3_col7, #T_ebce9_row4_col7, #T_ebce9_row6_col7, #T_ebce9_row7_col7, #T_ebce9_row8_col7, #T_ebce9_row10_col7, #T_ebce9_row11_col7, #T_ebce9_row12_col7, #T_ebce9_row13_col7, #T_ebce9_row14_col7, #T_ebce9_row16_col7, #T_ebce9_row17_col7, #T_ebce9_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ebce9_row5_col7, #T_ebce9_row9_col7, #T_ebce9_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ebce9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebce9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ebce9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ebce9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ebce9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ebce9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ebce9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ebce9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ebce9_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebce9_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_ebce9_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ebce9_row0_col1" class="data row0 col1" >0.6050</td>
#       <td id="T_ebce9_row0_col2" class="data row0 col2" >0.6727</td>
#       <td id="T_ebce9_row0_col3" class="data row0 col3" >0.8201</td>
#       <td id="T_ebce9_row0_col4" class="data row0 col4" >0.5991</td>
#       <td id="T_ebce9_row0_col5" class="data row0 col5" >0.4128</td>
#       <td id="T_ebce9_row0_col6" class="data row0 col6" >0.2510</td>
#       <td id="T_ebce9_row0_col7" class="data row0 col7" >0.4490</td>
#     </tr>
#     <tr>
#       <th id="T_ebce9_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_ebce9_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ebce9_row1_col1" class="data row1 col1" >0.5983</td>
#       <td id="T_ebce9_row1_col2" class="data row1 col2" >0.6738</td>
#       <td id="T_ebce9_row1_col3" class="data row1 col3" >0.8208</td>
#       <td id="T_ebce9_row1_col4" class="data row1 col4" >0.5984</td>
#       <td id="T_ebce9_row1_col5" class="data row1 col5" >0.4125</td>
#       <td id="T_ebce9_row1_col6" class="data row1 col6" >0.2488</td>
#       <td id="T_ebce9_row1_col7" class="data row1 col7" >0.0930</td>
#     </tr>
#     <tr>
#       <th id="T_ebce9_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_ebce9_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ebce9_row2_col1" class="data row2 col1" >0.6012</td>
#       <td id="T_ebce9_row2_col2" class="data row2 col2" >0.6962</td>
#       <td id="T_ebce9_row2_col3" class="data row2 col3" >0.8343</td>
#       <td id="T_ebce9_row2_col4" class="data row2 col4" >0.5850</td>
#       <td id="T_ebce9_row2_col5" class="data row2 col5" >0.4181</td>
#       <td id="T_ebce9_row2_col6" class="data row2 col6" >0.2536</td>
#       <td id="T_ebce9_row2_col7" class="data row2 col7" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_ebce9_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_ebce9_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_ebce9_row3_col1" class="data row3 col1" >0.7014</td>
#       <td id="T_ebce9_row3_col2" class="data row3 col2" >0.7396</td>
#       <td id="T_ebce9_row3_col3" class="data row3 col3" >0.8599</td>
#       <td id="T_ebce9_row3_col4" class="data row3 col4" >0.5592</td>
#       <td id="T_ebce9_row3_col5" class="data row3 col5" >0.4547</td>
#       <td id="T_ebce9_row3_col6" class="data row3 col6" >0.2421</td>
#       <td id="T_ebce9_row3_col7" class="data row3 col7" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_ebce9_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_ebce9_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_ebce9_row4_col1" class="data row4 col1" >0.7291</td>
#       <td id="T_ebce9_row4_col2" class="data row4 col2" >0.7756</td>
#       <td id="T_ebce9_row4_col3" class="data row4 col3" >0.8806</td>
#       <td id="T_ebce9_row4_col4" class="data row4 col4" >0.5377</td>
#       <td id="T_ebce9_row4_col5" class="data row4 col5" >0.4369</td>
#       <td id="T_ebce9_row4_col6" class="data row4 col6" >0.3045</td>
#       <td id="T_ebce9_row4_col7" class="data row4 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_ebce9_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_ebce9_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_ebce9_row5_col1" class="data row5 col1" >0.7291</td>
#       <td id="T_ebce9_row5_col2" class="data row5 col2" >0.7756</td>
#       <td id="T_ebce9_row5_col3" class="data row5 col3" >0.8806</td>
#       <td id="T_ebce9_row5_col4" class="data row5 col4" >0.5377</td>
#       <td id="T_ebce9_row5_col5" class="data row5 col5" >0.4369</td>
#       <td id="T_ebce

# %%
print(best)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=6487, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
# functional API
evaluate_model(best)

# OOP API
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# functional API
plot_model(best)

# OOP API
s.plot_model(best)

# %%
# functional API
predict_model(best)

# OOP API
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_38a06">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38a06_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_38a06_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_38a06_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_38a06_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_38a06_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_38a06_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_38a06_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38a06_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38a06_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_38a06_row0_col1" class="data row0 col1" >0.6058</td>
#       <td id="T_38a06_row0_col2" class="data row0 col2" >0.6797</td>
#       <td id="T_38a06_row0_col3" class="data row0 col3" >0.8244</td>
#       <td id="T_38a06_row0_col4" class="data row0 col4" >0.5941</td>
#       <td id="T_38a06_row0_col5" class="data row0 col5" >0.4125</td>
#       <td id="T_38a06_row0_col6" class="data row0 col6" >0.2510</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_eb169">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb169_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eb169_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eb169_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eb169_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_eb169_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_eb169_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_eb169_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb169_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb169_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_eb169_row0_col1" class="data row0 col1" >0.6015</td>
#       <td id="T_eb169_row0_col2" class="data row0 col2" >0.6715</td>
#       <td id="T_eb169_row0_col3" class="data row0 col3" >0.8195</td>
#       <td id="T_eb169_row0_col4" class="data row0 col4" >0.5972</td>
#       <td id="T_eb169_row0_col5" class="data row0 col5" >0.4107</td>
#       <td id="T_eb169_row0_col6" class="data row0 col6" >0.2496</td>
#     </tr>
#   </tbody>
# </table>
#        총거래물량(kg)       평균가격(원)  총거래금액(원)  거래단위  등급명  prediction_label
# 17820      200.0  46010.000000    460100  20.0    3          0.496317
# 34558      440.0  34127.273438    750800  20.0    2          0.685972
# 11404       80.0  98350.000000    393400  20.0    0          0.606179
# 20310       90.0  10000.000000     90000  10.0    3          2.066883
# 41978     1590.0  19283.019531   3066000  10.0    3          2.845317
# ...          ...           ...       ...   ...  ...               ...
# 1130      1200.0  62125.000000   7455000  10.0    3          2.821476
# 51988      560.0  49107.144531   1375000  20.0    0          0.665266
# 48394      900.0  11222.222656   1010000  10.0    3          2.616373
# 6006       120.0  60000.000000    360000  20.0    0          0.491359
# 44186       10.0  32000.000000     32000  10.0    3          2.218176
#
# [19557 rows x 6 columns]

# %%
# functional API
predictions = predict_model(best, data=df_temp)
predictions.head()

# OOP API
predictions = s.predict_model(best, data=df_temp)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec99a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec99a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ec99a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ec99a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ec99a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ec99a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ec99a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ec99a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec99a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec99a_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ec99a_row0_col1" class="data row0 col1" >0.6008</td>
#       <td id="T_ec99a_row0_col2" class="data row0 col2" >0.6649</td>
#       <td id="T_ec99a_row0_col3" class="data row0 col3" >0.8154</td>
#       <td id="T_ec99a_row0_col4" class="data row0 col4" >0.6030</td>
#       <td id="T_ec99a_row0_col5" class="data row0 col5" >0.4102</td>
#       <td id="T_ec99a_row0_col6" class="data row0 col6" >0.2494</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fb519">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb519_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fb519_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fb519_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fb519_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fb519_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fb519_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fb519_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb519_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb519_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fb519_row0_col1" class="data row0 col1" >0.6008</td>
#       <td id="T_fb519_row0_col2" class="data row0 col2" >0.6649</td>
#       <td id="T_fb519_row0_col3" class="data row0 col3" >0.8154</td>
#       <td id="T_fb519_row0_col4" class="data row0 col4" >0.6030</td>
#       <td id="T_fb519_row0_col5" class="data row0 col5" >0.4102</td>
#       <td id="T_fb519_row0_col6" class="data row0 col6" >0.2494</td>
#     </tr>
#   </tbody>
# </table>
#    총거래물량(kg)        평균가격(원)  총거래금액(원)  거래단위  등급명  prediction_label
# 0     1800.0   62366.667969  11226000  10.0    3          2.828752
# 1     3840.0   95000.000000  36480000  10.0    3          3.054257
# 2     1200.0   60900.000000   7308000  10.0    3          2.828950
# 3      600.0   61300.000000   3678000  10.0    3          2.821917
# 4     3520.0  152875.562500  26906100  20.0    0          0.687866
